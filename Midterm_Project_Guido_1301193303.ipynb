# %% [markdown]
# ## Tugas Besar 1
# ### MK Visualisasi Data Gasal 2020/2021

# %% [markdown]
# <b>Nama<b>: Guido Tamara<br>
# <b>NIM<b>: 1301193303

# %% [markdown]
# #### Aturan umum:
# 1. Setiap soal dievaluasi berdasarkan _code program_ dan penjelasan yang dibuat.
# 2. File _midterm project_ yang telah dikerjakan harus di-submit melalui LMS.
# 4. <b><font color='red'>Setiap tindakan plagiarism akan berakibat pada ketidaklulusan pada MK ini.</font><b>

# %% [markdown]
# ### Kasus 1: Pima Indian Diabetes Data Set (Soal 1 - 2)
# Dataset ini berasal dari the National Institute of Diabetes and Digestive and Kidney Diseases. Tujuan dari pengumpulan dataset ini untuk dapat memprediksi secara diagnosis apakah seseorang mengidap penyakit diabetes atau tidak berdasarkan beberapa pengukuran diagnostik. Seluruh pasien pada dataset ini adalah perempuan keturunan India Pima yang berumur kurang dari 21 tahun.<br><br>
# Dataset terdiri dari beberapa variabel prediktor medis dan satu variabel target sebagai _outcome_. Variabel prediktor di antaranya jumlah kehamilan, BMI, level insulin, usia, dll.lin level, age, and so on. Dataset dapat diunduh melalui [tautan ini](https://www.dl.dropboxusercontent.com/s/3i3gfr8pih4jwd4/diabetes.csv?dl=0)

# %% [markdown]
# ### Import Library

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
warnings.filterwarnings('ignore')
import itertools

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#mengecek data null
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#menghitung data statistik
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ### Soal 1 (15 poin)
# Tampilkan visualisasi distribusi data untuk variabel "Glucose" dan "Insulin", lalu jelaskan hasil distribusinya.

# %% [markdown]
# #### Code

# %%
#pemanggilan kolom glucose dan insulin
df1 = df[['Glucose','Insulin']]
df1.head(10)
# Out:
#    Glucose  Insulin
# 0      148        0
# 1       85        0
# 2      183        0
# 3       89       94
# 4      137      168
# 5      116        0
# 6       78       88
# 7      115        0
# 8      197      543
# 9      125        0

# %%
# Histogram kolom glucose dan insulin
col = df1.columns[:2]
plt.subplots(figsize = (30, 5))
length = len(col)

for i, j in itertools.zip_longest(col, range(length)):
    plt.subplot((length/2), 3, j + 1)
    plt.subplots_adjust(wspace = 0.1,hspace = 0.5)
    df1[i].hist(bins = 10)
    plt.ylabel('Jumlah Orang')
    plt.xlabel('Tingkat')
    plt.title(i)
plt.show()

# %% [markdown]
# #### Penjelasan
# Dari kedua distribusi data antara Glucose dan Insulin, untuk distribusi data Glucose cukup merata atau Bell-shaped (symmetric) dimana persebaran data berpusat di sekitar mean dan pada tingkat antara 100 - 120 mencapai rata-rata tinggi yaitu sekitar 200 orang. Sedangkan untuk distribusi data Insulin adalah Right-skew dimana data tersebar berpusat di sekitar nilai minimum di tingkat antara 0 - 100 dengan jumlah orang sekitar hampir 400 orang lebih.

# %% [markdown]
# ### Soal 2 (25 poin)
# Tampilkan visualisasi dari korelasi (i) antar variabel dan (ii) antara variabel dan target, lalu jelaskan hasil korelasinya.

# %% [markdown]
# #### Code

# %% [markdown]
# ### Korelasi (i) antar variabel

# %%
#Correlation Matrix
plt.figure(figsize=[20,10])
sns.heatmap(df.corr(),annot=True, cmap='Blues', linecolor='Green', linewidths=1.5)
plt.title('Korelasi Antar Variabel')
plt.show()

# %%
corr = df.corr()
f, ax = plt.subplots(figsize=(12, 10))

mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, annot=True, mask = mask, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Korelasi (ii) antara variabel dan target

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr()[['Age']], annot=True, cmap='Blues', linecolor='Green', linewidths=1.5)
plt.title('Korelasi Antar Variabel dan Target')
# Out:
# Text(0.5, 1.0, 'Korelasi Antar Variabel dan Target')

# %% [markdown]
# #### Penjelasan
# Untuk Korelasi (i) melihat korelasi atau hubungan antar variabel yang bersifat kuantitatif disertai dengan pewarnaan, variabel Biru, putih dimana semakin kuat warnanya, semakin besar besaran korelasinya. Untuk nilai korelasi tertinggi ada pada variabel sama sebesar 1, untuk variabel yang berbeda terdapat korelasi positif yang kuat antara variabel Age dengan Pregnancies yaitu sebesar 0.54 dan korelasi terlemah/negatif yaitu pada variabel antara Age dengan SkinThickness yaitu sebesar -0.11.
#
# Korelasi (ii) antara variabel dan target. Disini saya ambil contoh untuk variabel target yaitu Age bisa diketahui dengan variabel sama memiliki korelasi tertinggi yaitu sebesar 1, untuk korelasi positif yang kuat dengan variabel Pregnancies yaitu sebesar 0.54 dan korelasi terlemah/negatif yaitu pada dengan variabel SkinThickness yaitu sebesar -0.11.

# %% [markdown]
# ### Kasus 2: Stock Market Analysis (Soal 3 - 4)
# Pada kasus ini, kita akan membandingkan beberapa parameter yang diturunkan dari data historis harga saham dari 3 perusahaan, yaitu Nasdaq, Nikkei dan Hang Seng. Data set dapat diunduh melalui [tautan ini](https://www.dl.dropboxusercontent.com/s/0wny6x5sio9nvap/stock_market.zip?dl=0).

# %% [markdown]
# ### Memanggil Data

# %%
#Nasdaq
Nasdaq_df = pd.read_csv('Nasdaq.csv')
#Nikkei
Nikkei_df = pd.read_csv('Nikkei.csv')
#Hang Seng
HangSeng_df = pd.read_csv('Hang_Seng.csv')

# %% [markdown]
# ### Soal 3 (30 poin)
# Lakukanlah _trend analysis_ nilai _daily percentage change_ dari ketiga harga saham tersebut selama tahun 2019, lalu tampilkan dan jelaskan melalui visualisasi data.
# _Trend analysis_ dilakukan dengan menggunakan hubungan berikut:
# ![output%2011.png](https://www.dl.dropboxusercontent.com/s/dxmrm74ksz5l9v2/trend_analysis_fig.png?dl=0)

# %% [markdown]
# #### Code

# %%
#Function trend analysis
def trend_analysis(x):
    if x > -0.5 and x <= 0.5:
        return "Slight or No change"
    elif x > 0.5 and x <= 1:
        return "Slight Positive"
    elif x > -1 and x <= -0.5:
        return "Slight Negative"
    elif x > 1 and x <= 3:
        return "Positive"
    elif x > -3 and x <= -1:
        return "Negative"
    elif x > 3 and x <= 7:
        return "Among top gainers"
    elif x > -7 and x <= -3:
        return "Among top losers"
    elif x > 7:
        return "Bull run"
    else:
        return "Bear drop"

# %% [markdown]
# ### Saham Nasdaq

# %%
#Mengecek data null
Nasdaq_df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Day-to-day percentage change(Daily returns)
Nasdaq_df["Daily_Percentage_Change"] = Nasdaq_df["Adj Close"].pct_change()*100
# drop null values
Nasdaq_df.dropna(inplace = True, axis = 0)
#Trend Analysis
Nasdaq_df["Trend"]= np.zeros(Nasdaq_df['Daily_Percentage_Change'].count())
Nasdaq_df["Trend"]= Nasdaq_df["Daily_Percentage_Change"].apply(lambda x:trend_analysis(x))
#Set Date/year 2019
Nasdaq_df['Date'] = pd.to_datetime(Nasdaq_df['Date'])
Nasdaq_df_2019 = Nasdaq_df[Nasdaq_df['Date'].dt.year == 2019]
Nasdaq_df_2019.head()
# Out:
#          Date         Open         High          Low        Close  \
# 49 2019-01-02  6506.910156  6693.709961  6506.879883  6665.939941
# 50 2019-01-03  6584.770020  6600.209961  6457.129883  6463.500000
# 51 2019-01-04  6567.140137  6760.689941  6554.240234  6738.859863
# 52 2019-01-07  6757.529785  6855.600098  6741.399902  6823.470215
# 53 2019-01-08  6893.439941  6909.580078  6795.859863  6897.000000
#
#       Adj Close      Volume  Daily_Percentage_Change                Trend
# 49  6665.939941  2261800000                 0.462078  Slight or No change
# 50  6463.500000  2607290000                -3.036930     Among top losers
# 51  6738.859863  2579550000                 4.260228    Among top gainers
# 52  6823.470215  2507550000                 1.255559             Positive
# 53  6897.000000  2380290000                 1.077601             Positive

# %%
#Visualisasi Trend Frequency dengan Pie-Chart
Nasdaq_df_pie_data = Nasdaq_df_2019.groupby('Trend')
pie_label = sorted([i for i in Nasdaq_df_2019.loc[:, 'Trend'].unique()])
plt.pie(Nasdaq_df_pie_data['Trend'].count(), labels = pie_label, 
        autopct = '%1.1f%%', radius = 2)
plt.title('Visualisasi Saham Nasdaq pada tahun 2019', y = 1.5)
plt.show()

# %% [markdown]
# ### Saham Nikkei

# %%
#Mengecek data null
Nikkei_df.isna().sum()
# Out:
# Date         0
# Open         3
# High         3
# Low          3
# Close        3
# Adj Close    3
# Volume       3
# dtype: int64

# %%
#Day-to-day percentage change(Daily returns)
Nikkei_df["Daily_Percentage_Change"] = Nikkei_df["Adj Close"].pct_change()*100
# drop null values
Nikkei_df.dropna(inplace = True, axis = 0)
#Trend Analysis
Nikkei_df["Trend"]= np.zeros(Nikkei_df['Daily_Percentage_Change'].count())
Nikkei_df["Trend"]= Nikkei_df["Daily_Percentage_Change"].apply(lambda x:trend_analysis(x))
#Set Date/year 2019
Nikkei_df['Date'] = pd.to_datetime(Nikkei_df['Date'])
Nikkei_df_2019 = Nikkei_df[Nikkei_df['Date'].dt.year == 2019]
Nikkei_df_2019.head()
# Out:
#          Date          Open          High           Low         Close  \
# 52 2019-01-04  19655.130859  19692.580078  19241.369141  19561.960938
# 53 2019-01-07  19944.609375  20266.220703  19920.800781  20038.970703
# 54 2019-01-08  20224.669922  20347.919922  20106.359375  20204.039063
# 55 2019-01-09  20366.300781  20494.349609  20331.199219  20427.060547
# 56 2019-01-10  20270.880859  20345.919922  20101.929688  20163.800781
#
#        Adj Close   Volume  Daily_Percentage_Change            Trend
# 52  19561.960938  91600.0                -2.262372         Negative
# 53  20038.970703  81500.0                 2.438456         Positive
# 54  20204.039063  86400.0                 0.823737  Slight Positive
# 55  20427.060547  72800.0                 1.103846         Positive
# 56  20163.800781  73700.0                -1.288779         Negative

# %%
#Visualisasi Trend Frequency dengan Pie-Chart
Nikkei_df_pie_data = Nikkei_df_2019.groupby('Trend')
pie_label = sorted([i for i in Nikkei_df_2019.loc[:, 'Trend'].unique()])
plt.pie(Nikkei_df_pie_data['Trend'].count(), labels = pie_label, 
        autopct = '%1.1f%%', radius = 2)
plt.title('Visualisasi Saham Nikkei pada tahun 2019', y = 1.5)
plt.show()

# %% [markdown]
# ### Saham HangSeng

# %%
#Mengecek data null
HangSeng_df.isna().sum()
# Out:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
#Day-to-day percentage change(Daily returns)
HangSeng_df["Daily_Percentage_Change"] = HangSeng_df["Adj Close"].pct_change()*100
# drop null values
HangSeng_df.dropna(inplace = True, axis = 0)
#Trend Analysis
HangSeng_df["Trend"]= HangSeng_df["Daily_Percentage_Change"].apply(lambda x:trend_analysis(x))
#Set Date/year 2019
HangSeng_df['Date'] = pd.to_datetime(HangSeng_df['Date'])
HangSeng_df_2019 = HangSeng_df[HangSeng_df['Date'].dt.year == 2019]
HangSeng_df_2019.head()
# Out:
#          Date          Open          High           Low         Close  \
# 50 2019-01-02  25824.439453  25824.439453  25055.269531  25130.349609
# 51 2019-01-03  25077.679688  25262.210938  24896.869141  25064.359375
# 52 2019-01-04  24946.119141  25626.029297  24924.730469  25626.029297
# 53 2019-01-07  26015.839844  26043.640625  25753.460938  25835.699219
# 54 2019-01-08  25852.500000  25960.890625  25688.500000  25875.449219
#
#        Adj Close        Volume  Daily_Percentage_Change                Trend
# 50  25130.349609  1.666316e+09                -2.767770             Negative
# 51  25064.359375  1.481292e+09                -0.262592  Slight or No change
# 52  25626.029297  1.708572e+09                 2.240911             Positive
# 53  25835.699219  1.447090e+09                 0.818191      Slight Positive
# 54  25875.449219  1.578206e+09                 0.153857  Slight or No change

# %%
#Visualisasi Trend Frequency dengan Pie-Chart
HangSeng_df_pie_data = HangSeng_df_2019.groupby('Trend')
pie_label = sorted([i for i in HangSeng_df_2019.loc[:, 'Trend'].unique()])
plt.pie(HangSeng_df_pie_data['Trend'].count(), labels = pie_label, 
        autopct = '%1.1f%%', radius = 2)
plt.title('Visualisasi Saham pada tahun HangSeng 2019', y = 1.5)
plt.show()

# %% [markdown]
# #### Penjelasan
# Melakukan Pemanggilan 3 dataset diberikan, melakukan fungsi untuk Trend Analysis selanjutnya melakukan/mengecek data null dari ketiga dataset tersebut, lakukan membuat kolom baru 'Daily_Percentage_Change' untuk melihat harian harga ketiga saham. Ini dapat dilakukan dengan menggunakan fungsi pct_change() bawaan dengan python, mendrop nilai null ketiga dataset, memanggil dan  tambahkan kolom baru ‘Trend’ yang nilainya berdasarkan persentase perubahan harian dan men-set date atau tahun 2019 sesuai perintah.
#
# Visualisai dari ketiga dataset harga saham dari 3 perusahaan, yaitu Nasdaq, Nikkei dan Hang Seng menggunakan Pie-Chart, berikut persentasi Trend Analysis dari terendah - terbesar.
# - Nasdaq = 0.4% (Among top Gainers), 1.6% (Among top losers), 9.1% (Slight Negative) & 9.1% (Negative), 16.7% (Slight Positive), 17.1% (Positive) dan 46.0% (Slight or No change)
# - Nikkei = 0.4% (Among top losers), 7.5% (Negative), 11.6% (Positive), 13.3% (Slight Positive), 14.5% (Slight Negative) dan 52.7% (Slight or No change)
# - Hang Seng = 0.4% (Among top Gainers), 12.2% (Negative), 11.4% (Slight Negative), 13.0% (Positive), 14.6% (Slight Positive) dan 48.4% (Slight or No change)

# %% [markdown]
# ### Soal 4 (30 poin)
# Lakukanlah analisis volatilitas dari ketiga harga saham tersebut selama tahun 2019, lalu tampilkan dan jelaskan hasil visualisasinya.

# %% [markdown]
# #### Code

# %%
#Set Index
Nasdaq_df_2019.set_index('Date', inplace=True)
Nikkei_df_2019.set_index('Date', inplace=True)
HangSeng_df_2019.set_index('Date', inplace=True)

# %%
# merge colomn Adj close values
combined_df = pd.concat([Nasdaq_df_2019["Adj Close"], Nikkei_df_2019["Adj Close"], HangSeng_df_2019["Adj Close"]], axis=1)
combined_df.columns = ["Nasdaq", "Nikkei", "HangSeng"]
combined_df.head()
# Out:
#                  Nasdaq        Nikkei      HangSeng
# Date
# 2019-01-02  6665.939941           NaN  25130.349609
# 2019-01-03  6463.500000           NaN  25064.359375
# 2019-01-04  6738.859863  19561.960938  25626.029297
# 2019-01-07  6823.470215  20038.970703  25835.699219
# 2019-01-08  6897.000000  20204.039063  25875.449219

# %%
#Mengecek data null
combined_df.isna().sum()
# Out:
# Nasdaq       8
# Nikkei      19
# HangSeng    14
# dtype: int64

# %%
# drop null values
combined_df.dropna(inplace = True, axis = 0)

# Day-to-day percentage change(Daily returns)
pct_chg_df = combined_df.pct_change()*100
pct_chg_df.dropna(inplace = True, how = "any", axis = 0)

#Visualisasi Volatilitas dengan line-chart
combined_vol = pct_chg_df[["Nasdaq", "Nikkei", "HangSeng"]].rolling(7).std()*np.sqrt(7)
combined_vol.plot(figsize = (15, 7), marker ='o')
plt.title('Volatilitas Saham Nasdaq, Nikkei, Hang Seng pada tahun 2019')
plt.xlabel('Tahun-Bulan')
plt.ylabel('Harga')
# Out:
# Text(0, 0.5, 'Harga')

# %% [markdown]
# #### Penjelasan
# Pertama melakukan set index 'date' untuk ketiga dataset saham yang sudah di set tahun 2019, melakukan merge atau penggabungan ketiga data set terhadap colom adj close tersebut, melakukan pengecekkan data null dan dilakukan mendrop data null pada dataset combine, seterusnya mengitung untuk pengembalian harian harga saham dari dataset yang sudah di combine, selanjutnya mengitung rata-rata 7 hari (moving average) dari pengembalian harian kemudian menghitung standar deviasi (yang merupakan akar kuadrat dari varians) dan memplot nilainya menggunakan fungsi rolling() dan std().
#
# Dari Visualisasi Volatilitas dengan line-chart, bisa diamati/dilihat dari ketiga saham tersebut memiliki harga relatif cenderung sama antara range harga 1-4 dan bisa dilihat juga pada trend analysis dari ketiga saham tersebut yaitu trend Slight or No Change. Terjadi sekitar antara 2019-08 dengan 2019-09 pada saham Nasdaq memilik harga tertinggi dan untuk harga saham terendah terjadi pada saham Nikkei yang terjadi sekitar antara 2019-10 dengan 2019-11.
